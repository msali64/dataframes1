# %% [markdown]
# <a href="https://colab.research.google.com/github/msali64/dataframes1/blob/main/dataframes1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['color'].isnull().sum()
# Out:
# 0

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.shape[0]
# Out:
# 6433

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
missing data handling
1) Imputation (fill in the blanks)
    1) stastical measures
    2) parameter

2) delete data
    rows
    columns
# Out:
#   File "<ipython-input-12-7cbc789e84f4>", line 2
#     1) Imputation (fill in the blanks)
#      ^
# SyntaxError: unmatched ')'

# %%
df.drop('pickup',axis=1,inplace=True)

# %%
df
# Out:
#                  dropoff  passengers  distance  fare   tip  tolls  total  \
# 0    2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0  12.95
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0   9.30
# 2    2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0  14.16
# 3    2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0  36.95
# 4    2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0  13.40
# ...                  ...         ...       ...   ...   ...    ...    ...
# 6428 2019-03-31 09:55:27           1      0.75   4.5  1.06    0.0   6.36
# 6429 2019-03-31 18:34:23           1     18.74  58.0  0.00    0.0  58.80
# 6430 2019-03-23 23:14:25           1      4.14  16.0  0.00    0.0  17.30
# 6431 2019-03-04 10:14:29           1      1.12   6.0  0.00    0.0   6.80
# 6432 2019-03-13 19:48:02           1      3.85  15.0  3.36    0.0  20.16
#
#        color      payment                      dropoff_zone pickup_borough  \
# ...

# %%
df.drop([2,3,6430,6432],axis=0,inplace=True)

# %%
a=np.random.randint(10,50,15)

# %%
df.iloc[2]
# Out:
# dropoff            2019-03-30 13:37:14
# passengers                           3
# distance                          2.16
# fare                               9.0
# tip                                1.1
# tolls                              0.0
# total                             13.4
# color                           yellow
# payment                    credit card
# dropoff_zone            Yorkville West
# pickup_borough               Manhattan
# dropoff_borough              Manhattan
# Name: 4, dtype: object

# %%
a
# Out:
# array([19, 37, 23, 10, 31, 42, 19, 13, 43, 38, 21, 36, 28, 34, 20])

# %%
a[a>40]
# Out:
# array([42, 43])

# %%
df[df['color']=='yellow']
# Out:
#                  dropoff  passengers  distance  fare   tip  tolls  total  \
# 0    2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0  12.95
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0   9.30
# 4    2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0  13.40
# 5    2019-03-11 10:47:31           1      0.49   7.5  2.16    0.0  12.96
# 6    2019-03-26 21:17:29           1      3.65  13.0  2.00    0.0  18.80
# ...                  ...         ...       ...   ...   ...    ...    ...
# 5446 2019-03-11 21:29:23           1      2.09   9.5  2.66    0.0  15.96
# 5447 2019-03-20 18:16:52           1      1.52   7.5  2.36    0.0  14.16
# 5448 2019-03-09 11:18:03           1      2.05   9.5  2.56    0.0  15.36
# 5449 2019-03-22 18:22:05           1      1.07   7.5  2.36    0.0  14.16
# 5450 2019-03-07 18:13:32           1      1.80   9.0  1.33    0.0  14.63
#
#        color      payment                  dropoff_zone pickup_borough  \
# ...

# %%
df[df['payment']=='cash']
# Out:
#                  dropoff  passengers  distance  fare  tip  tolls  total  \
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.0    0.0    9.3
# 10   2019-03-16 10:22:29           1      3.90  17.0  0.0    0.0   17.8
# 13   2019-03-19 08:09:17           1      1.75  10.5  0.0    0.0   13.8
# 14   2019-03-27 12:25:48           0      2.90  11.5  0.0    0.0   14.8
# 15   2019-03-16 18:13:57           3      2.09  13.5  0.0    0.0   16.8
# ...                  ...         ...       ...   ...  ...    ...    ...
# 6419 2019-03-16 10:47:33           1      1.54   8.5  0.0    0.0    9.3
# 6420 2019-03-16 15:46:18           2      1.20   7.0  0.0    0.0    7.8
# 6422 2019-03-22 20:36:07           1      4.02  16.0  0.0    0.0   17.3
# 6424 2019-03-30 20:59:55           1      1.70   8.0  0.0    0.0    9.3
# 6427 2019-03-23 18:49:12           1      7.07  20.0  0.0    0.0   20.0
#
#        color payment                dropoff_zone pickup_borough  \
# ...

# %%
df['payment']=='cash'
# Out:
# 1       True
# 10      True
# 13      True
# 14      True
# 15      True
#         ...
# 6419    True
# 6420    True
# 6422    True
# 6424    True
# 6427    True
# Name: payment, Length: 1811, dtype: bool

# %%
df[df['total']>15]
# Out:
#                  dropoff  passengers  distance  fare  tip  tolls  total  \
# 10   2019-03-16 10:22:29           1      3.90  17.0  0.0    0.0  17.80
# 15   2019-03-16 18:13:57           3      2.09  13.5  0.0    0.0  16.80
# 16   2019-03-15 12:54:28           1      2.12  13.0  0.0    0.0  16.30
# 26   2019-03-03 03:02:14           1      3.35  13.5  0.0    0.0  17.30
# 29   2019-03-06 08:27:11           1      0.92  12.0  0.0    0.0  15.30
# ...                  ...         ...       ...   ...  ...    ...    ...
# 6405 2019-03-21 18:51:08           2      3.88  16.5  0.0    0.0  18.30
# 6407 2019-03-07 16:50:03           1      2.68  12.0  0.0    0.0  16.55
# 6408 2019-03-04 07:49:25           1      6.48  22.0  0.0    0.0  25.55
# 6422 2019-03-22 20:36:07           1      4.02  16.0  0.0    0.0  17.30
# 6427 2019-03-23 18:49:12           1      7.07  20.0  0.0    0.0  20.00
#
#        color payment                   dropoff_zone pickup_borough  \
# ...

# %%
df[(df['payment']=='cash') & (df['total']>15)]
# Out:
#                  dropoff  passengers  distance  fare  tip  tolls  total  \
# 10   2019-03-16 10:22:29           1      3.90  17.0  0.0    0.0  17.80
# 15   2019-03-16 18:13:57           3      2.09  13.5  0.0    0.0  16.80
# 16   2019-03-15 12:54:28           1      2.12  13.0  0.0    0.0  16.30
# 26   2019-03-03 03:02:14           1      3.35  13.5  0.0    0.0  17.30
# 29   2019-03-06 08:27:11           1      0.92  12.0  0.0    0.0  15.30
# ...                  ...         ...       ...   ...  ...    ...    ...
# 6405 2019-03-21 18:51:08           2      3.88  16.5  0.0    0.0  18.30
# 6407 2019-03-07 16:50:03           1      2.68  12.0  0.0    0.0  16.55
# 6408 2019-03-04 07:49:25           1      6.48  22.0  0.0    0.0  25.55
# 6422 2019-03-22 20:36:07           1      4.02  16.0  0.0    0.0  17.30
# 6427 2019-03-23 18:49:12           1      7.07  20.0  0.0    0.0  20.00
#
#        color payment                   dropoff_zone pickup_borough  \
# ...
